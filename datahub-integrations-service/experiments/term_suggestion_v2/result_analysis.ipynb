# %%
import os
import pandas as pd

# Directory containing subdirectories of experiments
main_dir = "Tuesday_tests_17-9/"

# %%
# Function to extract threshold value from directory name
def get_threshold_from_dir(dir_name):
    return dir_name.split("_")[-1]

# Function to process a run directory and collect data for all thresholds
def process_run(run_path):
    threshold_dirs = [d for d in os.listdir(run_path) if os.path.isdir(os.path.join(run_path, d)) and d.startswith("threshold_")]
    run_data = {}
    
    for threshold_dir in threshold_dirs:
        threshold_value = get_threshold_from_dir(threshold_dir)
        csv_file = f"final_stats_threshold_{threshold_value}.csv"
        csv_path = os.path.join(run_path, threshold_dir, csv_file)
        
        if os.path.exists(csv_path):
            df = pd.read_csv(csv_path, index_col=0)
            if "description" in df.columns:
                # Extract required metrics
                run_data[threshold_value] = df["description"]
    
    return run_data

# Main function to collect data from all experiments and runs
def collect_data(main_dir):
    # Dictionary to hold the data, outer dict for subdirectory, inner dict for threshold data
    all_data = {}

    sub_dirs = [d for d in os.listdir(main_dir) if os.path.isdir(os.path.join(main_dir, d))]
    for sub_dir in sub_dirs:
        sub_dir_path = os.path.join(main_dir, sub_dir)
        run_dirs = [d for d in os.listdir(sub_dir_path) if os.path.isdir(os.path.join(sub_dir_path, d))]
        for run_dir in run_dirs:
            run_path = os.path.join(sub_dir_path, run_dir)
            run_data = process_run(run_path)
            
            if run_data:
                # Store the data by subdirectory, run, and threshold
                if sub_dir not in all_data:
                    all_data[sub_dir] = {}
                all_data[sub_dir][run_dir] = run_data

    return all_data

# Convert collected data into a DataFrame with multi-level columns
def create_dataframe_and_save(all_data):
    dataframe_dict = {}
    for sub_dir, run_data in all_data.items():
        # Initialize an empty DataFrame to store the final combined results
        df_combined = pd.DataFrame()
        threshold_list = []
        counter = 1
        for run, thresholds in run_data.items():
            for threshold, metrics in thresholds.items():
                # Create multi-level column with format (threshold, run)
                column_name = (threshold, f"run_{counter}")
                df_combined[column_name] = metrics
                threshold_list.append(str(threshold))
            counter += 1

        # # For each experiment (sub_dir), calculate average across all runs for each threshold
        for threshold in set(threshold_list):
            threshold_cols = [col for col in df_combined.columns if threshold in col]
            avg_column_name = (threshold, f"run_average")
            df_combined[avg_column_name] = df_combined[threshold_cols].mean(axis=1)

        # Sort the columns for better readability
        df_combined = df_combined.sort_index(axis=1, level=[0, 1])
        save_to_csv(df_combined, f"{sub_dir}.csv")
        dataframe_dict[sub_dir] = df_combined
    return dataframe_dict

# Save the DataFrame to a CSV
def save_to_csv(df, output_file="aggregated_results.csv"):
    df.to_csv(output_file)

# %%
data = collect_data(main_dir)
df_dict = create_dataframe_and_save(data)
# save_to_csv(df_result)
# print("Data aggregation completed and saved to 'aggregated_results.csv'")

# %%
data
# Out:
# {'claude_no_example_pr': {'output_09-17-2024_17-26-02': {'7': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               17.000000
#    TN                               21.000000
#    FP1                              16.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.500000
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.913043
#    recall_none_for_all_tables        0.567568
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               17.000000
#    TN                               32.000000
#    FP1                               5.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.739130
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.941176
#    recall_none_for_all_tables        0.864865
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               17.000000
#    TN                               32.000000
#    FP1                               5.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.739130
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.941176
#    recall_none_for_all_tables        0.864865
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               12.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                8.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.600000
#    precision_none_for_all_tables     0.822222
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               12.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                8.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.600000
#    precision_none_for_all_tables     0.822222
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                0.00000
#    fake_terms_count                 18.00000
#    actual_column_count              57.00000
#    skipped_columns_count             0.00000
#    TP                                6.00000
#    TN                               37.00000
#    FP1                               0.00000
#    FP2                               0.00000
#    FN                               14.00000
#    precision_term_for_all_tables     1.00000
#    recall_term_for_all_tables        0.30000
#    precision_none_for_all_tables     0.72549
#    recall_none_for_all_tables        1.00000
#    threshold                         9.50000
#    Name: description, dtype: float64},
#   'output_09-17-2024_17-52-08': {'7': fake_columns_count                0.000000
#    fake_terms_count                 10.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               18.000000
#    TN                               26.000000
#    FP1                              11.000000
#    FP2                               1.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.600000
#    recall_term_for_all_tables        0.900000
#    precision_none_for_all_tables     0.962963
#    recall_none_for_all_tables        0.702703
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                0.000000
#    fake_terms_count                 10.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               18.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               1.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.900000
#    recall_term_for_all_tables        0.900000
#    precision_none_for_all_tables     0.972973
#    recall_none_for_all_tables        0.972973
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                0.000000
#    fake_terms_count                 10.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               18.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               1.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.900000
#    recall_term_for_all_tables        0.900000
#    precision_none_for_all_tables     0.972973
#    recall_none_for_all_tables        0.972973
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                0.000000
#    fake_terms_count                 10.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                6.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.700000
#    precision_none_for_all_tables     0.860465
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                0.000000
#    fake_terms_count                 10.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                6.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.700000
#    precision_none_for_all_tables     0.860465
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                0.000000
#    fake_terms_count                 10.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                                8.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                               12.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.400000
#    precision_none_for_all_tables     0.755102
#    recall_none_for_all_tables        1.000000
#    threshold                         9.500000
#    Name: description, dtype: float64},
#   'output_09-17-2024_18-03-45': {'7': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               22.000000
#    FP1                              15.000000
#    FP2                               3.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.454545
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.916667
#    recall_none_for_all_tables        0.594595
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               30.000000
#    FP1                               7.000000
#    FP2                               1.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.652174
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.882353
#    recall_none_for_all_tables        0.810811
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               30.000000
#    FP1                               7.000000
#    FP2                               1.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.652174
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.882353
#    recall_none_for_all_tables        0.810811
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                5.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.880952
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                5.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.880952
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                0.000000
#    fake_terms_count                 18.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                                8.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                               12.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.400000
#    precision_none_for_all_tables     0.755102
#    recall_none_for_all_tables        1.000000
#    threshold                         9.500000
#    Name: description, dtype: float64}},
#  'claude_no_example_pr_redef_confidence': {'output_09-17-2024_16-24-53': {'1': fake_columns_count                0.000000
#    fake_terms_count                 14.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               13.000000
#    FP1                              24.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.431818
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.351351
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                0.000000
#    fake_terms_count                 14.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               13.000000
#    FP1                              24.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.431818
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.351351
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                0.000000
#    fake_terms_count                 14.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               18.000000
#    FP1                              19.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.487179
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.486486
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                0.000000
#    fake_terms_count                 14.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               28.000000
#    FP1                               9.000000
#    FP2                               0.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.678571
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     0.965517
#    recall_none_for_all_tables        0.756757
#    threshold                         4.000000
#    Name: description, dtype: float64},
#   'output_09-17-2024_16-41-56': {'1': fake_columns_count                0.000000
#    fake_terms_count                  9.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               18.000000
#    TN                                9.000000
#    FP1                              28.000000
#    FP2                               1.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.382979
#    recall_term_for_all_tables        0.900000
#    precision_none_for_all_tables     0.900000
#    recall_none_for_all_tables        0.243243
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                0.000000
#    fake_terms_count                  9.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               18.000000
#    TN                                9.000000
#    FP1                              28.000000
#    FP2                               1.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.382979
#    recall_term_for_all_tables        0.900000
#    precision_none_for_all_tables     0.900000
#    recall_none_for_all_tables        0.243243
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                0.000000
#    fake_terms_count                  9.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               18.000000
#    TN                               13.000000
#    FP1                              24.000000
#    FP2                               1.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.418605
#    recall_term_for_all_tables        0.900000
#    precision_none_for_all_tables     0.928571
#    recall_none_for_all_tables        0.351351
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                0.000000
#    fake_terms_count                  9.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               17.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.944444
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.923077
#    recall_none_for_all_tables        0.972973
#    threshold                         4.000000
#    Name: description, dtype: float64},
#   'output_09-17-2024_16-55-55': {'1': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               14.000000
#    FP1                              23.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.441860
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.378378
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               14.000000
#    FP1                              23.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.441860
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.378378
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               17.000000
#    FP1                              20.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.475000
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.459459
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.950000
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     0.972973
#    recall_none_for_all_tables        0.972973
#    threshold                         4.000000
#    Name: description, dtype: float64}},
#  'claude_pr': {'output_09-17-2024_13-55-49': {'7': fake_columns_count                5.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               15.000000
#    FP1                              22.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.452381
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.405405
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                5.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               27.000000
#    FP1                              10.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.633333
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.729730
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                5.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               29.000000
#    FP1                               8.000000
#    FP2                               0.000000
#    FN                                1.000000
#    precision_term_for_all_tables     0.703704
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     0.966667
#    recall_none_for_all_tables        0.783784
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                5.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               12.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                8.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.600000
#    precision_none_for_all_tables     0.822222
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                5.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               12.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                8.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.600000
#    precision_none_for_all_tables     0.822222
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                5.00000
#    fake_terms_count                  3.00000
#    actual_column_count              57.00000
#    skipped_columns_count             0.00000
#    TP                                6.00000
#    TN                               37.00000
#    FP1                               0.00000
#    FP2                               0.00000
#    FN                               14.00000
#    precision_term_for_all_tables     1.00000
#    recall_term_for_all_tables        0.30000
#    precision_none_for_all_tables     0.72549
#    recall_none_for_all_tables        1.00000
#    threshold                         9.50000
#    Name: description, dtype: float64},
#   'output_09-17-2024_14-08-16': {'7': fake_columns_count                7.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               17.000000
#    FP1                              20.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.475000
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.459459
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                7.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               27.000000
#    FP1                              10.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.633333
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.729730
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                7.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               19.000000
#    TN                               31.000000
#    FP1                               6.000000
#    FP2                               1.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.730769
#    recall_term_for_all_tables        0.950000
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.837838
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                7.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               13.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840909
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                7.000000
#    fake_terms_count                  3.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               13.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840909
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                7.00
#    fake_terms_count                  3.00
#    actual_column_count              57.00
#    skipped_columns_count             0.00
#    TP                                7.00
#    TN                               37.00
#    FP1                               0.00
#    FP2                               0.00
#    FN                               13.00
#    precision_term_for_all_tables     1.00
#    recall_term_for_all_tables        0.35
#    precision_none_for_all_tables     0.74
#    recall_none_for_all_tables        1.00
#    threshold                         9.50
#    Name: description, dtype: float64},
#   'output_09-17-2024_14-22-41': {'7': fake_columns_count                5.000000
#    fake_terms_count                  5.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               17.000000
#    TN                               16.000000
#    FP1                              21.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.435897
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.888889
#    recall_none_for_all_tables        0.432432
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                5.000000
#    fake_terms_count                  5.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               17.000000
#    TN                               25.000000
#    FP1                              12.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.566667
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.925926
#    recall_none_for_all_tables        0.675676
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                5.000000
#    fake_terms_count                  5.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               17.000000
#    TN                               28.000000
#    FP1                               9.000000
#    FP2                               0.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.653846
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.903226
#    recall_none_for_all_tables        0.756757
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                5.000000
#    fake_terms_count                  5.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               11.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                9.000000
#    precision_term_for_all_tables     0.916667
#    recall_term_for_all_tables        0.550000
#    precision_none_for_all_tables     0.800000
#    recall_none_for_all_tables        0.972973
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                5.000000
#    fake_terms_count                  5.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               11.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                9.000000
#    precision_term_for_all_tables     0.916667
#    recall_term_for_all_tables        0.550000
#    precision_none_for_all_tables     0.800000
#    recall_none_for_all_tables        0.972973
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                5.00000
#    fake_terms_count                  5.00000
#    actual_column_count              57.00000
#    skipped_columns_count             2.00000
#    TP                                6.00000
#    TN                               37.00000
#    FP1                               0.00000
#    FP2                               0.00000
#    FN                               14.00000
#    precision_term_for_all_tables     1.00000
#    recall_term_for_all_tables        0.30000
#    precision_none_for_all_tables     0.72549
#    recall_none_for_all_tables        1.00000
#    threshold                         9.50000
#    Name: description, dtype: float64}},
#  'claude_pr_redef_confidence': {'output_09-17-2024_18-18-46': {'1': fake_columns_count               11.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               16.000000
#    TN                               16.000000
#    FP1                              21.000000
#    FP2                               1.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.421053
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.842105
#    recall_none_for_all_tables        0.432432
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count               11.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               16.000000
#    TN                               16.000000
#    FP1                              21.000000
#    FP2                               1.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.421053
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.842105
#    recall_none_for_all_tables        0.432432
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count               11.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               16.000000
#    TN                               17.000000
#    FP1                              20.000000
#    FP2                               1.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.432432
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.850000
#    recall_none_for_all_tables        0.459459
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count               11.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               13.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     0.928571
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.837209
#    recall_none_for_all_tables        0.972973
#    threshold                         4.000000
#    Name: description, dtype: float64},
#   'output_09-17-2024_18-29-48': {'1': fake_columns_count               10.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               17.000000
#    FP1                              20.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.447368
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.894737
#    recall_none_for_all_tables        0.459459
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count               10.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               17.000000
#    FP1                              20.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.447368
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.894737
#    recall_none_for_all_tables        0.459459
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count               10.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               20.000000
#    FP1                              17.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.485714
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.909091
#    recall_none_for_all_tables        0.540541
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count               10.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               16.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                4.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.902439
#    recall_none_for_all_tables        1.000000
#    threshold                         4.000000
#    Name: description, dtype: float64},
#   'output_09-17-2024_18-37-58': {'1': fake_columns_count                8.000000
#    fake_terms_count                  6.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               15.000000
#    FP1                              22.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.425000
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.882353
#    recall_none_for_all_tables        0.405405
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                8.000000
#    fake_terms_count                  6.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               15.000000
#    FP1                              22.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.425000
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.882353
#    recall_none_for_all_tables        0.405405
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                8.000000
#    fake_terms_count                  6.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               17.000000
#    FP1                              20.000000
#    FP2                               1.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.447368
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.894737
#    recall_none_for_all_tables        0.459459
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                8.000000
#    fake_terms_count                  6.000000
#    actual_column_count              57.000000
#    skipped_columns_count             7.000000
#    TP                               17.000000
#    TN                               34.000000
#    FP1                               3.000000
#    FP2                               0.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.850000
#    recall_term_for_all_tables        0.850000
#    precision_none_for_all_tables     0.918919
#    recall_none_for_all_tables        0.918919
#    threshold                         4.000000
#    Name: description, dtype: float64}},
#  'consistencty_tests_regular_prompt': {'term_suggestion_output_09-17-2024_09-17-38': {'7': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              55.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               19.000000
#    FP1                              18.000000
#    FP2                               3.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.416667
#    recall_term_for_all_tables        0.833333
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.513514
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              55.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               26.000000
#    FP1                              11.000000
#    FP2                               3.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.517241
#    recall_term_for_all_tables        0.833333
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.702703
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              55.000000
#    skipped_columns_count             0.000000
#    TP                               15.000000
#    TN                               26.000000
#    FP1                              11.000000
#    FP2                               3.000000
#    FN                                0.000000
#    precision_term_for_all_tables     0.517241
#    recall_term_for_all_tables        0.833333
#    precision_none_for_all_tables     1.000000
#    recall_none_for_all_tables        0.702703
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              55.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.933333
#    recall_term_for_all_tables        0.777778
#    precision_none_for_all_tables     0.900000
#    recall_none_for_all_tables        0.972973
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              55.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               36.000000
#    FP1                               1.000000
#    FP2                               0.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.933333
#    recall_term_for_all_tables        0.777778
#    precision_none_for_all_tables     0.900000
#    recall_none_for_all_tables        0.972973
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              55.000000
#    skipped_columns_count             0.000000
#    TP                                6.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                               12.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.333333
#    precision_none_for_all_tables     0.755102
#    recall_none_for_all_tables        1.000000
#    threshold                         9.500000
#    Name: description, dtype: float64},
#   'term_suggestion_output_09-17-2024_10-19-28': {'7': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               15.000000
#    TN                               12.000000
#    FP1                              25.000000
#    FP2                               3.000000
#    FN                                2.000000
#    precision_term_for_all_tables     0.348837
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.857143
#    recall_none_for_all_tables        0.324324
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               15.000000
#    TN                               28.000000
#    FP1                               9.000000
#    FP2                               2.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.576923
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.903226
#    recall_none_for_all_tables        0.756757
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               15.000000
#    TN                               28.000000
#    FP1                               9.000000
#    FP2                               2.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.576923
#    recall_term_for_all_tables        0.750000
#    precision_none_for_all_tables     0.903226
#    recall_none_for_all_tables        0.756757
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               13.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840909
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               13.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840909
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                0.000000
#    fake_terms_count                  0.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                                5.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                               15.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.250000
#    precision_none_for_all_tables     0.711538
#    recall_none_for_all_tables        1.000000
#    threshold                         9.500000
#    Name: description, dtype: float64},
#   'term_suggestion_output_09-17-2024_11-56-05': {'7': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               16.000000
#    TN                               18.000000
#    FP1                              19.000000
#    FP2                               1.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.444444
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.857143
#    recall_none_for_all_tables        0.486486
#    threshold                         7.000000
#    Name: description, dtype: float64,
#    '7.5': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               16.000000
#    TN                               29.000000
#    FP1                               8.000000
#    FP2                               1.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.640000
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.906250
#    recall_none_for_all_tables        0.783784
#    threshold                         7.500000
#    Name: description, dtype: float64,
#    '8': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               16.000000
#    TN                               29.000000
#    FP1                               8.000000
#    FP2                               1.000000
#    FN                                3.000000
#    precision_term_for_all_tables     0.640000
#    recall_term_for_all_tables        0.800000
#    precision_none_for_all_tables     0.906250
#    recall_none_for_all_tables        0.783784
#    threshold                         8.000000
#    Name: description, dtype: float64,
#    '8.5': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               13.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840909
#    recall_none_for_all_tables        1.000000
#    threshold                         8.500000
#    Name: description, dtype: float64,
#    '9': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               13.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840909
#    recall_none_for_all_tables        1.000000
#    threshold                         9.000000
#    Name: description, dtype: float64,
#    '9.5': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                                4.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                               16.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.200000
#    precision_none_for_all_tables     0.698113
#    recall_none_for_all_tables        1.000000
#    threshold                         9.500000
#    Name: description, dtype: float64}},
#  'tests_redefined_confidence': {'output_09-17-2024_12-08-34': {'1': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               10.000000
#    TN                               24.000000
#    FP1                              13.000000
#    FP2                               1.000000
#    FN                                9.000000
#    precision_term_for_all_tables     0.416667
#    recall_term_for_all_tables        0.500000
#    precision_none_for_all_tables     0.727273
#    recall_none_for_all_tables        0.648649
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               10.000000
#    TN                               24.000000
#    FP1                              13.000000
#    FP2                               1.000000
#    FN                                9.000000
#    precision_term_for_all_tables     0.416667
#    recall_term_for_all_tables        0.500000
#    precision_none_for_all_tables     0.727273
#    recall_none_for_all_tables        0.648649
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               10.000000
#    TN                               24.000000
#    FP1                              13.000000
#    FP2                               1.000000
#    FN                                9.000000
#    precision_term_for_all_tables     0.416667
#    recall_term_for_all_tables        0.500000
#    precision_none_for_all_tables     0.727273
#    recall_none_for_all_tables        0.648649
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                0.000000
#    fake_terms_count                  8.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               10.000000
#    TN                               35.000000
#    FP1                               2.000000
#    FP2                               0.000000
#    FN                               10.000000
#    precision_term_for_all_tables     0.833333
#    recall_term_for_all_tables        0.500000
#    precision_none_for_all_tables     0.777778
#    recall_none_for_all_tables        0.945946
#    threshold                         4.000000
#    Name: description, dtype: float64},
#   'output_09-17-2024_13-00-24': {'1': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               24.000000
#    FP1                              13.000000
#    FP2                               1.000000
#    FN                                5.000000
#    precision_term_for_all_tables     0.500000
#    recall_term_for_all_tables        0.700000
#    precision_none_for_all_tables     0.827586
#    recall_none_for_all_tables        0.648649
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               24.000000
#    FP1                              13.000000
#    FP2                               1.000000
#    FN                                5.000000
#    precision_term_for_all_tables     0.500000
#    recall_term_for_all_tables        0.700000
#    precision_none_for_all_tables     0.827586
#    recall_none_for_all_tables        0.648649
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               24.000000
#    FP1                              13.000000
#    FP2                               1.000000
#    FN                                5.000000
#    precision_term_for_all_tables     0.500000
#    recall_term_for_all_tables        0.700000
#    precision_none_for_all_tables     0.827586
#    recall_none_for_all_tables        0.648649
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                0.000000
#    fake_terms_count                  1.000000
#    actual_column_count              57.000000
#    skipped_columns_count             0.000000
#    TP                               14.000000
#    TN                               37.000000
#    FP1                               0.000000
#    FP2                               0.000000
#    FN                                6.000000
#    precision_term_for_all_tables     1.000000
#    recall_term_for_all_tables        0.700000
#    precision_none_for_all_tables     0.860465
#    recall_none_for_all_tables        1.000000
#    threshold                         4.000000
#    Name: description, dtype: float64},
#   'output_09-17-2024_13-39-14': {'1': fake_columns_count                0.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               13.000000
#    TN                               21.000000
#    FP1                              16.000000
#    FP2                               3.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.406250
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840000
#    recall_none_for_all_tables        0.567568
#    threshold                         1.000000
#    Name: description, dtype: float64,
#    '2': fake_columns_count                0.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               13.000000
#    TN                               21.000000
#    FP1                              16.000000
#    FP2                               3.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.406250
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840000
#    recall_none_for_all_tables        0.567568
#    threshold                         2.000000
#    Name: description, dtype: float64,
#    '3': fake_columns_count                0.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               13.000000
#    TN                               21.000000
#    FP1                              16.000000
#    FP2                               3.000000
#    FN                                4.000000
#    precision_term_for_all_tables     0.406250
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.840000
#    recall_none_for_all_tables        0.567568
#    threshold                         3.000000
#    Name: description, dtype: float64,
#    '4': fake_columns_count                0.000000
#    fake_terms_count                  4.000000
#    actual_column_count              57.000000
#    skipped_columns_count             2.000000
#    TP                               13.000000
#    TN                               35.000000
#    FP1                               2.000000
#    FP2                               0.000000
#    FN                                7.000000
#    precision_term_for_all_tables     0.866667
#    recall_term_for_all_tables        0.650000
#    precision_none_for_all_tables     0.833333
#    recall_none_for_all_tables        0.945946
#    threshold                         4.000000
#    Name: description, dtype: float64}}}

# %%
df_dict.keys()
# Out:
# dict_keys(['claude_no_example_pr', 'claude_no_example_pr_redef_confidence', 'claude_pr', 'claude_pr_redef_confidence', 'consistencty_tests_regular_prompt', 'tests_redefined_confidence'])

# %%
df_dict["best_prompt"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_dict["best_prompt"]
#
# KeyError: 'best_prompt'
